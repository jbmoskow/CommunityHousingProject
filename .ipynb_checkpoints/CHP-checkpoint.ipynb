# %% [markdown]
# # Community Housing Survey Project
# This notebook is designed to do exploratory data analysis for the 2020 PhD-Community Initiative Housing
# Survey dataset
#
# Coded by Josh Moskowitz in February 2020
#
# ---

# %% [markdown]
# Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import excel data

# %%
survey = pd.read_excel('F:/Users/Josh/Dropbox/PhD-CI/KCH_01312020.xlsx',index_col=None,header=0)
questions = survey.iloc[0][:] # grab questions and store for later
survey.drop(index=[0,1],inplace=True) # remove first 2 rows
survey.reset_index(drop=True, inplace=True) # reset index

# %%
survey.head()
# Out:
#              StartDate              EndDate      Status       IPAddress  \
# 0  2020-01-27 11:30:32  2020-01-27 11:35:10  IP Address  67.193.119.167
# 1  2020-01-27 11:32:03  2020-01-27 11:36:52  IP Address  104.245.145.11
# 2  2020-01-27 11:30:40  2020-01-27 11:38:33  IP Address  24.140.243.109
# 3  2020-01-27 11:51:43  2020-01-27 11:56:05  IP Address   72.39.239.108
# 4  2020-01-27 11:55:00  2020-01-27 11:57:32  IP Address   67.216.57.217
#
#   Progress Duration (in seconds) Finished         RecordedDate  \
# 0      100                   278     True  2020-01-27 11:35:20
# 1      100                   288     True  2020-01-27 11:36:52
# 2      100                   472     True  2020-01-27 11:38:33
# 3      100                   261     True  2020-01-27 11:56:05
# 4      100                   151     True  2020-01-27 11:57:33
#
#           ResponseId RecipientLastName  ...      substance_use  \
# 0  R_1MMr6qTANeNL5mi               NaN  ...         Not at all
# 1  R_PBqyA9TCRf7jisp               NaN  ...           A little
# 2  R_0iiMUtQkUo9fqAF               NaN  ...         Not at all
# 3  R_VUast3SOPXkYRfH               NaN  ...         Not at all
# 4  R_2v96TNCsMb5mcVy               NaN  ...  A moderate amount
#
#                                               gender                   age  \
# 0                                             Female              Under 25
# 1                                             Female  25 - 65
# 2                                               Male              Under 25
# 3  I prefer not to disclose information concernin...  25 - 65
# 4                                             Female  25 - 65
#
#                fam_status fam_status_5_TEXT       first_nation  \
# 0  Single with dependents               NaN                Yes
# 1    Single no dependents               NaN                 No
# 2  Couple with dependents               NaN                 No
# 3  Single with dependents               NaN  Prefer not to say
# 4  Single with dependents               NaN                Yes
#
#         vis_minority       can_residency can_residency_3_TEXT  \
# 0                No   Canadian Citizen\t                  NaN
# 1                No   Canadian Citizen\t                  NaN
# 2                Yes  Permanent Resident                  NaN
# 3  Prefer not to say  Canadian Citizen\t                  NaN
# 4                No   Canadian Citizen\t                  NaN
#
#                                                 info
# 0                                                NaN
# 1                                                NaN
# 2  there are people in very need of that house \n...
# 3                                                NaN
# 4  Housing costs may be cheap however electric fu...
#
# [5 rows x 43 columns]

# %%
list(survey.columns)
# Out:
# ['StartDate',
#  'EndDate',
#  'Status',
#  'IPAddress',
#  'Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'RecipientLastName',
#  'RecipientFirstName',
#  'RecipientEmail',
#  'ExternalReference',
#  'LocationLatitude',
#  'LocationLongitude',
#  'DistributionChannel',
#  'UserLanguage',
#  'consent',
#  'num_applied',
#  'num_applied_explain',
#  'num_applied_explain_2_TEXT',
#  'num_applied_explain_3_TEXT',
#  'private_housing',
#  'current_living_arr',
#  'current_living_arr_6_TEXT',
#  'why_move',
#  'why_move_7_TEXT',
#  'subsidy',
#  'employment',
#  'income_stable',
#  'utilities',
#  'debt',
#  'mental_health',
#  'substance_use',
#  'gender',
#  'age',
#  'fam_status',
#  'fam_status_5_TEXT',
#  'first_nation',
#  'vis_minority',
#  'can_residency',
#  'can_residency_3_TEXT',
#  'info']

# %% [markdown]
# Analyze the basic demographic data
